# %% [markdown]
# # Compras de Ecommerce
# ## Neste caso aplicado, se analisará dos dados referente à compras na loja online da Amazon.

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/Ecommerce%20Purchases?raw=true')

# %%
data1.head(5)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
len(data1)
# Out:
# 10000

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
np.shape(data1)
# Out:
# (10000, 14)

# %%
data1['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
data1['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %%
data1['Purchase Price'].max()
# Out:
# 99.99

# %%
data1['Purchase Price'].min()
# Out:
# 0.0

# %%
data1['Purchase Price'].idxmax()
# Out:
# 2092

# %%
data1['Purchase Price'].idxmin()
# Out:
# 2876

# %%
data1.iloc[2092]
# Out:
# Address                     63773 Shelton Greens\nAshleyton, MA 00493
# Lot                                                             56 lu
# AM or PM                                                           AM
# Browser Info        Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# Company                                                   Pitts Group
# Credit Card                                             4292741269160
# CC Exp Date                                                     06/18
# CC Security Code                                                  824
# CC Provider                                                   Maestro
# Email                                        heatherwoodard@lloyd.com
# Job                                            Surveyor, hydrographic
# IP Address                                            172.197.216.229
# Language                                                           el
# ...

# %%
type(data1.iloc[2092])
# Out:
# pandas.core.series.Series

# %%
pd.DataFrame(data1.iloc[2092])
# Out:
#                                                                2092
# Address                   63773 Shelton Greens\nAshleyton, MA 00493
# Lot                                                           56 lu
# AM or PM                                                         AM
# Browser Info      Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# Company                                                 Pitts Group
# Credit Card                                           4292741269160
# CC Exp Date                                                   06/18
# CC Security Code                                                824
# CC Provider                                                 Maestro
# Email                                      heatherwoodard@lloyd.com
# Job                                          Surveyor, hydrographic
# IP Address                                          172.197.216.229
# Language                                                         el
# ...

# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/daniel-usp/LIT/master/Ecommerce%20Purchases?raw=true', index_col='Language')

# %%
data1.head(10)
# Out:
#                                                     Address    Lot AM or PM  \
# Language
# el        16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# fr        9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# de                         Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# es                    7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# es        23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ru        7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# de           93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# pt        260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# ru                  2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# zh          3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                                Browser Info  \
# Language
# ...

# %%
len(data1.loc[['el']])
# Out:
# 1137

# %%
data1.query('Language =="el"').count()
# Out:
# Address             1137
# Lot                 1137
# AM or PM            1137
# Browser Info        1137
# Company             1137
# Credit Card         1137
# CC Exp Date         1137
# CC Security Code    1137
# CC Provider         1137
# Email               1137
# Job                 1137
# IP Address          1137
# Purchase Price      1137
# dtype: int64

# %%
data1['CC Provider'].nunique()
# Out:
# 10

# %%
len(data1.query('Language =="en"'))
# Out:
# 1098

# %%
data1.query('Language =="en" or Language =="es"')
# Out:
#                                                 Address  ... Purchase Price
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  ...          78.04
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  ...          77.82
# 11               349 Laurie Parks\nThomasview, ID 08970  ...          19.26
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  ...          39.65
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  ...          33.62
# ...                                                 ...  ...            ...
# 9973     92126 Daniel Streets\nNorth Patricia, IA 10477  ...          83.30
# 9976  5419 Cruz Island Apt. 033\nLake Todd, AK 24863...  ...          37.73
# 9979  00490 Joseph Haven Apt. 149\nWest Keithfurt, S...  ...          14.55
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  ...          60.83
# 9998               0096 English Rest\nRoystad, IA 12457  ...          38.84
#
# [2193 rows x 14 columns]

# %%
len(data1.query('Language =="en" or Language =="es"'))
# Out:
# 2193

# %%
filtro = data1['Language'] =='en'

# %%
data1[filtro].count()[0]
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data1.query('Job =="Lawyer"').count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Purchase Price      30
# dtype: int64

# %%
len(data1.query('Job =="Lawyer"'))
# Out:
# 30

# %%
np.shape(data1[data1['Job'] =='Lawyer'])
# Out:
# (30, 14)

# %%
data1['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
data1['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
Jobs_Data = pd.DataFrame(data1['Job'].value_counts())

# %%
Jobs_Data.sort_index()
# Out:
#                                   Job
# Academic librarian                 11
# Accommodation manager              17
# Accountant, chartered              20
# Accountant, chartered certified    18
# Accountant, chartered management   15
# ...                               ...
# Water quality scientist            18
# Web designer                       20
# Wellsite geologist                 24
# Writer                             10
# Youth worker                       18
#
# [623 rows x 1 columns]

# %%
data1['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Purchasing manager                   27
# Research officer, political party    27
# Name: Job, dtype: int64

# %%
data1.query('Lot == "90 WT"')['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
data1.query('Lot == "90 WT"')
# Out:
#                                                Address  ... Purchase Price
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  ...           75.1
#
# [1 rows x 14 columns]

# %%
data1.query('Lot == "90 WT"')
# Out:
#                                                Address  ... Purchase Price
# 513  50398 Mccoy Rest Suite 597\nSouth Garyborough,...  ...           75.1
#
# [1 rows x 14 columns]

# %%
filtro = data1['Credit Card'] == 4926535242672853

# %%
data1[filtro]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
filtro = (data1['CC Provider'] == 'American Express') & (data1['Purchase Price'] > 95)

# %%
np.shape(data1[filtro])
# Out:
# (39, 14)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
data1['CC Exp Date'].head(5)
# Out:
# 0    02/20
# 1    11/18
# 2    08/19
# 3    02/24
# 4    10/25
# Name: CC Exp Date, dtype: object

# %%
x = '02/20'
x
# Out:
# '02/20'

# %%
y = x.split('/')
y
# Out:
# ['02', '20']

# %%
Filtro = data1['CC Exp Date'].apply(lambda ano: ano.split('/')[-1]) == '25'

# %%
Filtro
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
data1[Filtro].count()[0]
# Out:
# 1033

# %%
sum(data1['CC Exp Date'].apply(lambda ano: ano.split('/')[-1]) == '25')
# Out:
# 1033

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data1['Email'].head(3)
# Out:
# 0                 pdunlap@yahoo.com
# 1                anthony41@reed.com
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
provedores = data1['Email'].apply(lambda x: x.split('@')[-1])

# %%
provedores
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
provedores.value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
